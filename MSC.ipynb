# %% [markdown]
# <a href="https://colab.research.google.com/github/DiogoFerreiraAlves02/DiogoFerreiraAlves02/blob/main/MSC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split, GridSearchCV, learning_curve
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Carregar o conjunto de dados completo
data, target = fetch_california_housing(return_X_y=True, as_frame=True)

scaler = StandardScaler()
data = scaler.fit_transform(data)

data_small = data[:3000]
target_small = target[:3000]

# %%
# Divisão dos dados de treino e teste (70-30)
X_train, X_test, y_train, y_test = train_test_split(data_small, target_small, test_size=0.3, random_state=42)

# Definir os parâmetros a serem explorados
param_grid = {
    'C': [1,100,200],
    'kernel': ['linear', 'poly', 'rbf'],
    'degree': [2,3],
    'gamma': ['scale', 'auto']
}

# Criar uma instância do modelo SVR
svr = SVR()

# Realizar a pesquisa pelos melhores hiperparâmetros usando validação cruzada
grid_search = GridSearchCV(svr, param_grid, cv=5)
grid_search.fit(X_train, y_train)

# Obter os resultados de validação cruzada para cada combinação de parâmetros
cv_results = grid_search.cv_results_
for mean_score, params in zip(cv_results["mean_test_score"], cv_results["params"]):
    print("\nParâmetros:", params)
    print("Score médio:", mean_score)

print("---------------------------------------------------------")

best_model = grid_search.best_estimator_

# Previsões nos conjuntos de treinamento e teste
y_train_pred = best_model.predict(X_train)
y_test_pred = best_model.predict(X_test)


# Cálculo do coeficiente de determinação (R²) e erro médio quadrático nos conjuntos de treino e teste
r2_test = r2_score(y_test, y_test_pred)
r2_train = r2_score(y_train, y_train_pred)
train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)

print("\nParâmetros do melhor modelo:", grid_search.best_params_)
print(f'R² do conjunto de teste: {r2_test}  Erro médio quadrático: {test_mse}')
print(f'R² do conjunto de treino: {r2_train}  Erro médio quadrático: {train_mse}')
print()

# Criar a curva de aprendizagem
train_sizes, train_scores, test_scores = learning_curve(best_model, X_train, y_train, cv=5, scoring='neg_mean_squared_error')

# Calcular a média e o desvio padrão dos scores de treino e teste
train_scores_mean = -np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = -np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plotar a curva de aprendizagem
plt.figure(figsize=(10, 6))
plt.title("Curva de Aprendizagem")
plt.xlabel("Tamanho do Conjunto de Treino")
plt.ylabel("MSE")
plt.grid()

plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")

plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Treino")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Teste")

plt.legend(loc="best")
plt.show()
# Out:
# Parâmetros: {'C': 1, 'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}
# Score médio: 0.6747364636021616
#
# Parâmetros: {'C': 1, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# Score médio: 0.454696700224695
#
# Parâmetros: {'C': 1, 'degree': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# Score médio: 0.7857318058386942
#
# Parâmetros: {'C': 1, 'degree': 2, 'gamma': 'auto', 'kernel': 'linear'}
# Score médio: 0.6747364636021616
#
# Parâmetros: {'C': 1, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# Score médio: 0.4475246205917828
#
# Parâmetros: {'C': 1, 'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}
# Score médio: 0.7930491652353754
#
# Parâmetros: {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# Score médio: 0.6747364636021616
#
# Parâmetros: {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# Score médio: -6.74177513991869
#
# Parâmetros: {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# Score médio: 0.7857318058386942
#
# Parâmetros: {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# Score médio: 0.6747364636021616
#
# Parâmetros: {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# Score médio: -18.154963043319075
#
# Parâmetros: {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# Score médio: 0.7930491652353754
#
# Parâmetros: {'C': 100, 'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}
# Score médio: 0.6733054675755492
#
# Parâmetros: {'C': 100, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# Score médio: 0.24648961455992593
#
# Parâmetros: {'C': 100, 'degree': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# Score médio: 0.7965604232916931
#
# Parâmetros: {'C': 100, 'degree': 2, 'gamma': 'auto', 'kernel': 'linear'}
# Score médio: 0.6733054675755492
#
# Parâmetros: {'C': 100, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# Score médio: 0.22225174976872797
#
# Parâmetros: {'C': 100, 'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}
# Score médio: 0.796219995733684
#
# Parâmetros: {'C': 100, 'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# Score médio: 0.6733054675755492
#
# Parâmetros: {'C': 100, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# Score médio: -165.15570484321174
#
# Parâmetros: {'C': 100, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# Score médio: 0.7965604232916931
#
# Parâmetros: {'C': 100, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# Score médio: 0.6733054675755492
#
# Parâmetros: {'C': 100, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# Score médio: -161.34564797033818
#
# Parâmetros: {'C': 100, 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# Score médio: 0.796219995733684
#
# Parâmetros: {'C': 200, 'degree': 2, 'gamma': 'scale', 'kernel': 'linear'}
# Score médio: 0.6729680943943585
#
# Parâmetros: {'C': 200, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# Score médio: 0.2646613210340234
#
# Parâmetros: {'C': 200, 'degree': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# Score médio: 0.7857019675947308
#
# Parâmetros: {'C': 200, 'degree': 2, 'gamma': 'auto', 'kernel': 'linear'}
# Score médio: 0.6729680943943585
#
# Parâmetros: {'C': 200, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# Score médio: 0.17304282244651567
#
# Parâmetros: {'C': 200, 'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}
# Score médio: 0.7846228085061921
#
# Parâmetros: {'C': 200, 'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# Score médio: 0.6729680943943585
#
# Parâmetros: {'C': 200, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# Score médio: -156.40786465858613
#
# Parâmetros: {'C': 200, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# Score médio: 0.7857019675947308
#
# Parâmetros: {'C': 200, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# Score médio: 0.6729680943943585
#
# Parâmetros: {'C': 200, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# Score médio: -199.76406973041597
#
# Parâmetros: {'C': 200, 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# Score médio: 0.7846228085061921
# ---------------------------------------------------------
#
# Parâmetros do melhor modelo: {'C': 100, 'degree': 2, 'gamma': 'scale', 'kernel': 'rbf'}
# R² do conjunto de teste: 0.8196229902892692  Erro médio quadrático: 0.15954660689200764
# R² do conjunto de treino: 0.8626728803937572  Erro médio quadrático: 0.1282143898268912

# %%
# Explorar diferentes valores para os argumentos do BaggingRegressor
n_estimators_values = [5, 10, 20, 100]
max_samples_values = [0.5, 0.7, 1.0]
max_features_values = [0.5, 0.7, 1.0]

best_score = -float('inf')  # Valor inicial para comparar com os scores encontrados

for n_estimators in n_estimators_values:
    for max_samples in max_samples_values:
        for max_features in max_features_values:
            # Criar uma instância do BaggingRegressor
            bagging_model = BaggingRegressor(estimator=best_model, n_estimators=n_estimators, max_samples=max_samples, max_features=max_features)

            # Treinar o modelo de BaggingRegressor
            bagging_model.fit(X_train, y_train)

            # Avaliar o desempenho do modelo no conjunto de teste
            test_predictions = bagging_model.predict(X_test)
            test_mse = mean_squared_error(y_test, test_predictions)
            r2_test = r2_score(y_test, test_predictions)

            print(f"'n_estimators': {n_estimators}, 'max_samples': {max_samples}, 'max_features': {max_features}")
            print(f"R² do conjunto de teste: {r2_test}")
            print(f"Erro médio quadrático do conjunto de teste: {test_mse}\n")

            # Verificar se o score atual é melhor que o melhor score anterior
            if r2_test > best_score:
                best_score = r2_test
                best_mse = test_mse
                best_n_estimators = n_estimators
                best_max_samples = max_samples
                best_max_features = max_features

print(f"Parâmetros do melhor modelo: 'n_estimators': {best_n_estimators}, 'max_samples': {best_max_samples}, 'max_features': {best_max_features}")
print(f"R² do melhor modelo: {best_score}  MSE: {best_mse}")

# Criar a curva de aprendizagem
train_sizes, train_scores, test_scores = learning_curve(bagging_model, X_train, y_train, cv=5, scoring='neg_mean_squared_error')

# Calcular a média e o desvio padrão dos scores de treino e teste
train_scores_mean = -np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = -np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plotar a curva de aprendizagem
plt.figure(figsize=(10, 6))
plt.title("Curva de Aprendizagem")
plt.xlabel("Tamanho do Conjunto de Treino")
plt.ylabel("MSE")
plt.grid()

plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")

plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Treino")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Teste")

plt.legend(loc="best")
plt.show()
# Out:
# 'n_estimators': 5, 'max_samples': 0.5, 'max_features': 0.5
# R² do conjunto de teste: 0.7922893040541896
# Erro médio quadrático do conjunto de teste: 0.18372372846449297
#
# 'n_estimators': 5, 'max_samples': 0.5, 'max_features': 0.7
# R² do conjunto de teste: 0.8134278403586884
# Erro médio quadrático do conjunto de teste: 0.16502632491259425
#
# 'n_estimators': 5, 'max_samples': 0.5, 'max_features': 1.0
# R² do conjunto de teste: 0.8212752305651292
# Erro médio quadrático do conjunto de teste: 0.15808517158932398
#
# 'n_estimators': 5, 'max_samples': 0.7, 'max_features': 0.5
# R² do conjunto de teste: 0.7944547194001947
# Erro médio quadrático do conjunto de teste: 0.18180838087379367
#
# 'n_estimators': 5, 'max_samples': 0.7, 'max_features': 0.7
# R² do conjunto de teste: 0.6522531857301039
# Erro médio quadrático do conjunto de teste: 0.3075881142682366
#
# 'n_estimators': 5, 'max_samples': 0.7, 'max_features': 1.0
# R² do conjunto de teste: 0.8249300047176882
# Erro médio quadrático do conjunto de teste: 0.1548524601926081
#
# 'n_estimators': 5, 'max_samples': 1.0, 'max_features': 0.5
# R² do conjunto de teste: 0.7683482770593578
# Erro médio quadrático do conjunto de teste: 0.20489998384571378
#
# 'n_estimators': 5, 'max_samples': 1.0, 'max_features': 0.7
# R² do conjunto de teste: 0.7420597619331591
# Erro médio quadrático do conjunto de teste: 0.2281526333676262
#
# 'n_estimators': 5, 'max_samples': 1.0, 'max_features': 1.0
# R² do conjunto de teste: 0.8125789347425016
# Erro médio quadrático do conjunto de teste: 0.16577719671633118
#
# 'n_estimators': 10, 'max_samples': 0.5, 'max_features': 0.5
# R² do conjunto de teste: 0.788559881333937
# Erro médio quadrático do conjunto de teste: 0.1870224678195611
#
# 'n_estimators': 10, 'max_samples': 0.5, 'max_features': 0.7
# R² do conjunto de teste: 0.8325633744616441
# Erro médio quadrático do conjunto de teste: 0.14810061169620956
#
# 'n_estimators': 10, 'max_samples': 0.5, 'max_features': 1.0
# R² do conjunto de teste: 0.8252574076337844
# Erro médio quadrático do conjunto de teste: 0.15456286661062404
#
# 'n_estimators': 10, 'max_samples': 0.7, 'max_features': 0.5
# R² do conjunto de teste: 0.8243075948993424
# Erro médio quadrático do conjunto de teste: 0.15540299251805575
#
# 'n_estimators': 10, 'max_samples': 0.7, 'max_features': 0.7
# R² do conjunto de teste: 0.822340916974074
# Erro médio quadrático do conjunto de teste: 0.1571425533985094
#
# 'n_estimators': 10, 'max_samples': 0.7, 'max_features': 1.0
# R² do conjunto de teste: 0.8133454827870277
# Erro médio quadrático do conjunto de teste: 0.16509917161923057
#
# 'n_estimators': 10, 'max_samples': 1.0, 'max_features': 0.5
# R² do conjunto de teste: 0.79914416743657
# Erro médio quadrático do conjunto de teste: 0.177660482404915
#
# 'n_estimators': 10, 'max_samples': 1.0, 'max_features': 0.7
# R² do conjunto de teste: 0.833905368032075
# Erro médio quadrático do conjunto de teste: 0.14691359500834822
#
# 'n_estimators': 10, 'max_samples': 1.0, 'max_features': 1.0
# R² do conjunto de teste: 0.8146869767632805
# Erro médio quadrático do conjunto de teste: 0.16391259683112178
#
# 'n_estimators': 20, 'max_samples': 0.5, 'max_features': 0.5
# R² do conjunto de teste: 0.8062447393200237
# Erro médio quadrático do conjunto de teste: 0.17137990289639216
#
# 'n_estimators': 20, 'max_samples': 0.5, 'max_features': 0.7
# R² do conjunto de teste: 0.8241000986807526
# Erro médio quadrático do conjunto de teste: 0.15558652653756308
#
# 'n_estimators': 20, 'max_samples': 0.5, 'max_features': 1.0
# R² do conjunto de teste: 0.826198352512545
# Erro médio quadrático do conjunto de teste: 0.1537305844760027
#
# 'n_estimators': 20, 'max_samples': 0.7, 'max_features': 0.5
# R² do conjunto de teste: 0.8118332172896141
# Erro médio quadrático do conjunto de teste: 0.16643679679230067
#
# 'n_estimators': 20, 'max_samples': 0.7, 'max_features': 0.7
# R² do conjunto de teste: 0.8249577952140045
# Erro médio quadrático do conjunto de teste: 0.15482787901456213
#
# 'n_estimators': 20, 'max_samples': 0.7, 'max_features': 1.0
# R² do conjunto de teste: 0.81722993014926
# Erro médio quadrático do conjunto de teste: 0.16166331026811565
#
# 'n_estimators': 20, 'max_samples': 1.0, 'max_features': 0.5
# R² do conjunto de teste: 0.7657446260976132
# Erro médio quadrático do conjunto de teste: 0.20720295847171327
#
# 'n_estimators': 20, 'max_samples': 1.0, 'max_features': 0.7
# R² do conjunto de teste: 0.8415485371393419
# Erro médio quadrático do conjunto de teste: 0.14015307880441602
#
# 'n_estimators': 20, 'max_samples': 1.0, 'max_features': 1.0
# R² do conjunto de teste: 0.8194181120871699
# Erro médio quadrático do conjunto de teste: 0.15972782523032858
#
# 'n_estimators': 100, 'max_samples': 0.5, 'max_features': 0.5
# R² do conjunto de teste: 0.79485956678673
# Erro médio quadrático do conjunto de teste: 0.18145028630878016
#
# 'n_estimators': 100, 'max_samples': 0.5, 'max_features': 0.7
# R² do conjunto de teste: 0.8263494573720163
# Erro médio quadrático do conjunto de teste: 0.1535969295958592
#
# 'n_estimators': 100, 'max_samples': 0.5, 'max_features': 1.0
# R² do conjunto de teste: 0.8237407575347258
# Erro médio quadrático do conjunto de teste: 0.15590437004022015
#
# 'n_estimators': 100, 'max_samples': 0.7, 'max_features': 0.5
# R² do conjunto de teste: 0.7904792047965129
# Erro médio quadrático do conjunto de teste: 0.18532479278617792
#
# 'n_estimators': 100, 'max_samples': 0.7, 'max_features': 0.7
# R² do conjunto de teste: 0.829365316639697
# Erro médio quadrático do conjunto de teste: 0.15092934954342382
#
# 'n_estimators': 100, 'max_samples': 0.7, 'max_features': 1.0
# R² do conjunto de teste: 0.8211633040877161
# Erro médio quadrático do conjunto de teste: 0.1581841725081288
#
# 'n_estimators': 100, 'max_samples': 1.0, 'max_features': 0.5
# R² do conjunto de teste: 0.8108677751616502
# Erro médio quadrático do conjunto de teste: 0.16729074717053494
#
# 'n_estimators': 100, 'max_samples': 1.0, 'max_features': 0.7
# R² do conjunto de teste: 0.8357274719483183
# Erro médio quadrático do conjunto de teste: 0.14530191235706436
#
# 'n_estimators': 100, 'max_samples': 1.0, 'max_features': 1.0
# R² do conjunto de teste: 0.8184577561101893
# Erro médio quadrático do conjunto de teste: 0.16057727681942752
#
# Parâmetros do melhor modelo: 'n_estimators': 20, 'max_samples': 1.0, 'max_features': 0.7
# R² do melhor modelo: 0.8415485371393419  MSE: 0.14015307880441602

# %%
# Explorar diferentes valores para os argumentos do RandomForestRegressor
n_estimators_values = [5, 100, 200, 300]
max_features_values = ['sqrt', 'log2']
max_leaf_nodes_values = [None, 10, 100]
min_samples_leaf_values = [1, 5, 10]
max_depth_values = [10,50,80]
bootstrap_values = [True, False]

best_score = -float('inf')  # Valor inicial para comparar com os scores encontrados

for n_estimators in n_estimators_values:
    for max_features in max_features_values:
        for max_leaf_nodes in max_leaf_nodes_values:
          for max_depth in max_depth_values:
            for bootstrap in bootstrap_values:
              for min_samples_leaf in min_samples_leaf_values:
                  # Criar uma instância do RandomForestRegressor
                  rf_model = RandomForestRegressor(n_estimators=n_estimators, max_features=max_features,
                                                  max_leaf_nodes=max_leaf_nodes, min_samples_leaf=min_samples_leaf, max_depth = max_depth, bootstrap = bootstrap)

                  # Treinar o modelo de RandomForestRegressor
                  rf_model.fit(X_train, y_train)

                  # Avaliar o desempenho do modelo no conjunto de teste
                  test_predictions = rf_model.predict(X_test)
                  r2_test = r2_score(y_test, test_predictions)
                  test_mse = mean_squared_error(y_test, test_predictions)

                  print(f"'n_estimators': {n_estimators}, 'max_features': {max_features}, 'max_leaf_nodes': {max_leaf_nodes}, 'min_samples_leaf': {min_samples_leaf}, 'max_depth': {max_depth}, 'bootstrap': {bootstrap}")
                  print(f"R² do conjunto de teste: {r2_test}")
                  print(f"Erro médio quadrático do conjunto de teste: {test_mse}\n")

                  # Verificar se o score atual é melhor que o melhor score anterior
                  if r2_test > best_score:
                      best_score = r2_test
                      best_mse = test_mse
                      best_n_estimators = n_estimators
                      best_max_features = max_features
                      best_max_leaf_nodes = max_leaf_nodes
                      best_min_samples_leaf = min_samples_leaf
                      best_max_depth = max_depth
                      best_bootstrap = bootstrap

print(f"Parâmetros do melhor modelo: 'n_estimators': {best_n_estimators}, 'max_features': {best_max_features}, 'max_leaf_nodes': {best_max_leaf_nodes}, 'min_samples_leaf': {best_min_samples_leaf}, 'max_depth': {best_max_depth}, 'bootstrap': {best_bootstrap}")
print(f"R² do melhor modelo: {best_score} MSE: {best_mse}")

# Criar a curva de aprendizagem
train_sizes, train_scores, test_scores = learning_curve(rf_model, X_train, y_train, cv=5, scoring='neg_mean_squared_error')

# Calcular a média e o desvio padrão dos scores de treino e teste
train_scores_mean = -np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = -np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plotar a curva de aprendizagem
plt.figure(figsize=(10, 6))
plt.title("Curva de Aprendizagem")
plt.xlabel("Tamanho do Conjunto de Treino")
plt.ylabel("MSE")
plt.grid()

plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")

plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Treino")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Teste")

plt.legend(loc="best")
plt.show()
# Out:
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8277531662782673
# Erro médio quadrático do conjunto de teste: 0.15235532461850862
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8518690456299902
# Erro médio quadrático do conjunto de teste: 0.13102440928204315
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8418697554539439
# Erro médio quadrático do conjunto de teste: 0.13986895561017684
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8407224394781738
# Erro médio quadrático do conjunto de teste: 0.1408837765746704
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8615598505435573
# Erro médio quadrático do conjunto de teste: 0.12245272354176197
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8442036250033588
# Erro médio quadrático do conjunto de teste: 0.1378046073424299
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8549559447147403
# Erro médio quadrático do conjunto de teste: 0.12829399327404
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8362144521516499
# Erro médio quadrático do conjunto de teste: 0.14487116988500684
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8434394719372211
# Erro médio quadrático do conjunto de teste: 0.1384805140394303
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8457237701774165
# Erro médio quadrático do conjunto de teste: 0.13646001245812
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8633768533505145
# Erro médio quadrático do conjunto de teste: 0.12084555291049265
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8666896140907004
# Erro médio quadrático do conjunto de teste: 0.1179153583342031
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8556800628396388
# Erro médio quadrático do conjunto de teste: 0.12765349817989333
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8461064973718162
# Erro médio quadrático do conjunto de teste: 0.13612148358833936
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8281259412922608
# Erro médio quadrático do conjunto de teste: 0.15202559862564427
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8492032269223944
# Erro médio quadrático do conjunto de teste: 0.13338237236208444
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.866939369110882
# Erro médio quadrático do conjunto de teste: 0.1176944456686249
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8550359856158007
# Erro médio quadrático do conjunto de teste: 0.12822319570290142
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.7812808802291995
# Erro médio quadrático do conjunto de teste: 0.19346087108218568
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.7441358840742895
# Erro médio quadrático do conjunto de teste: 0.2263162671719457
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.7101766546018858
# Erro médio quadrático do conjunto de teste: 0.25635379714141354
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.7709065638106218
# Erro médio quadrático do conjunto de teste: 0.20263713465403727
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.7166642187498677
# Erro médio quadrático do conjunto de teste: 0.250615433652271
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.7755541791394217
# Erro médio quadrático do conjunto de teste: 0.19852623794365018
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.7620632959135824
# Erro médio quadrático do conjunto de teste: 0.2104591591408183
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.7667002467482849
# Erro médio quadrático do conjunto de teste: 0.20635769536121426
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.794394641111644
# Erro médio quadrático do conjunto de teste: 0.18186152116645907
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.7444280152809739
# Erro médio quadrático do conjunto de teste: 0.22605787203129832
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.7508926525928772
# Erro médio quadrático do conjunto de teste: 0.22033978772800653
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.767416752574409
# Erro médio quadrático do conjunto de teste: 0.20572393347792445
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.796397732104671
# Erro médio quadrático do conjunto de teste: 0.18008975229333105
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.7658290770932041
# Erro médio quadrático do conjunto de teste: 0.20712826009514743
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.7523601720999206
# Erro médio quadrático do conjunto de teste: 0.2190417411628035
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.7513197023931096
# Erro médio quadrático do conjunto de teste: 0.21996205474135672
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.7778525156050277
# Erro médio quadrático do conjunto de teste: 0.1964933193074467
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.759750124248617
# Erro médio quadrático do conjunto de teste: 0.2125051997692543
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8412412610377378
# Erro médio quadrático do conjunto de teste: 0.1404248698684134
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8497820658515323
# Erro médio quadrático do conjunto de teste: 0.13287037924705797
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8409327272649827
# Erro médio quadrático do conjunto de teste: 0.1406977733644498
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8595472312139442
# Erro médio quadrático do conjunto de teste: 0.12423292039456495
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8530084843328625
# Erro médio quadrático do conjunto de teste: 0.13001655590263395
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8536988548350064
# Erro médio quadrático do conjunto de teste: 0.12940591116862912
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.828405990065199
# Erro médio quadrático do conjunto de teste: 0.151777890608097
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8407251504317655
# Erro médio quadrático do conjunto de teste: 0.1408813786889992
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8595666936956632
# Erro médio quadrático do conjunto de teste: 0.12421570549048742
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8459598949694231
# Erro médio quadrático do conjunto de teste: 0.1362511559667735
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.853993536171784
# Erro médio quadrático do conjunto de teste: 0.12914526039349616
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.857364746252075
# Erro médio quadrático do conjunto de teste: 0.12616336635781425
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8327660874829317
# Erro médio quadrático do conjunto de teste: 0.1479213084980296
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8558252794556561
# Erro médio quadrático do conjunto de teste: 0.12752505155364624
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8310091395520387
# Erro médio quadrático do conjunto de teste: 0.14947535954538568
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8251894347028069
# Erro médio quadrático do conjunto de teste: 0.15462298985202472
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8483884955886519
# Erro médio quadrático do conjunto de teste: 0.13410301641775244
#
# 'n_estimators': 5, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8591150304965081
# Erro médio quadrático do conjunto de teste: 0.1246152094572
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8638268335042573
# Erro médio quadrático do conjunto de teste: 0.12044753762676255
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8558733818346091
# Erro médio quadrático do conjunto de teste: 0.12748250416161605
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8583135750264796
# Erro médio quadrático do conjunto de teste: 0.12532411078017422
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8485457715109982
# Erro médio quadrático do conjunto de teste: 0.1339639031250086
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8667782241151255
# Erro médio quadrático do conjunto de teste: 0.11783698122419162
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8666785205679652
# Erro médio quadrático do conjunto de teste: 0.11792517074828911
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8302688577688617
# Erro médio quadrático do conjunto de teste: 0.15013015167681779
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.857227514716844
# Erro médio quadrático do conjunto de teste: 0.12628475004102194
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.859478055909755
# Erro médio quadrático do conjunto de teste: 0.12429410715601416
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8681001129352858
# Erro médio quadrático do conjunto de teste: 0.11666774753812888
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8680500121936657
# Erro médio quadrático do conjunto de teste: 0.11671206251674544
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8455937683934017
# Erro médio quadrático do conjunto de teste: 0.13657500130044933
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8495604022917838
# Erro médio quadrático do conjunto de teste: 0.13306644452658664
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8606208794810624
# Erro médio quadrático do conjunto de teste: 0.12328325980151654
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.864605297912562
# Erro médio quadrático do conjunto de teste: 0.11975897229834076
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8596009631369002
# Erro médio quadrático do conjunto de teste: 0.12418539357280889
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8784643408802867
# Erro médio quadrático do conjunto de teste: 0.10750040739687666
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8709978269137864
# Erro médio quadrático do conjunto de teste: 0.11410466905182555
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.7881982721526912
# Erro médio quadrático do conjunto de teste: 0.18734231743887375
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.7905874656953608
# Erro médio quadrático do conjunto de teste: 0.18522903413546102
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8060088371758436
# Erro médio quadrático do conjunto de teste: 0.17158856245185802
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.7702588742117645
# Erro médio quadrático do conjunto de teste: 0.20321002738567004
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.7661946842345349
# Erro médio quadrático do conjunto de teste: 0.2068048742105031
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.7637773956842365
# Erro médio quadrático do conjunto de teste: 0.2089430080375218
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.7724544336910779
# Erro médio quadrático do conjunto de teste: 0.20126801678400966
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.7869118484005421
# Erro médio quadrático do conjunto de teste: 0.1884801816545509
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.7955469202864166
# Erro médio quadrático do conjunto de teste: 0.180842310165999
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.7820806081813921
# Erro médio quadrático do conjunto de teste: 0.19275349777882705
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.792904323472849
# Erro médio quadrático do conjunto de teste: 0.1831797330762938
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.7921188862844306
# Erro médio quadrático do conjunto de teste: 0.18387446595017795
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.7914665171379809
# Erro médio quadrático do conjunto de teste: 0.18445149782316445
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.7811608405651281
# Erro médio quadrático do conjunto de teste: 0.19356704825590504
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.791457987396584
# Erro médio quadrático do conjunto de teste: 0.1844590425280008
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.7971739783380865
# Erro médio quadrático do conjunto de teste: 0.17940314897923484
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.7960762438384668
# Erro médio quadrático do conjunto de teste: 0.18037411426446434
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.7892935848046861
# Erro médio quadrático do conjunto de teste: 0.18637349432005218
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8453045257152374
# Erro médio quadrático do conjunto de teste: 0.13683084148730842
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8725561394482522
# Erro médio quadrático do conjunto de teste: 0.1127263144724363
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8625580741994764
# Erro médio quadrático do conjunto de teste: 0.12156977733106351
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8544197079932946
# Erro médio quadrático do conjunto de teste: 0.12876830399431838
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8624728257592447
# Erro médio quadrático do conjunto de teste: 0.12164518106130394
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8542270964059652
# Erro médio quadrático do conjunto de teste: 0.12893867229821576
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8450271588979179
# Erro médio quadrático do conjunto de teste: 0.13707617726839674
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8610325210841053
# Erro médio quadrático do conjunto de teste: 0.12291915563366046
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8437470250560062
# Erro médio quadrático do conjunto de teste: 0.13820847794891133
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8525414284094147
# Erro médio quadrático do conjunto de teste: 0.13042967500209346
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8591941907321066
# Erro médio quadrático do conjunto de teste: 0.12454519085000183
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.876327334060586
# Erro médio quadrático do conjunto de teste: 0.10939062715124057
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8413803522037064
# Erro médio quadrático do conjunto de teste: 0.14030184130942713
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8592099401237866
# Erro médio quadrático do conjunto de teste: 0.12453126023873824
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8563154657457396
# Erro médio quadrático do conjunto de teste: 0.12709147324201317
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8464862194038049
# Erro médio quadrático do conjunto de teste: 0.13578561283705523
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.860112162422179
# Erro médio quadrático do conjunto de teste: 0.12373322890092163
#
# 'n_estimators': 5, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8690389984131573
# Erro médio quadrático do conjunto de teste: 0.11583728697946447
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8730404423612685
# Erro médio quadrático do conjunto de teste: 0.11229794011029573
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8710664704127712
# Erro médio quadrático do conjunto de teste: 0.1140439526813424
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8640342336031067
# Erro médio quadrático do conjunto de teste: 0.12026408862683982
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8716882398969892
# Erro médio quadrático do conjunto de teste: 0.11349398674258417
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8767015811812602
# Erro médio quadrático do conjunto de teste: 0.109059599054376
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.871279699424391
# Erro médio quadrático do conjunto de teste: 0.11385534790654636
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8807790329754344
# Erro médio quadrático do conjunto de teste: 0.1054530219214616
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8794123453902191
# Erro médio quadrático do conjunto de teste: 0.10666188089551935
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8661010342925406
# Erro médio quadrático do conjunto de teste: 0.11843596741754568
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8845688991604647
# Erro médio quadrático do conjunto de teste: 0.10210081926899477
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8822768526079366
# Erro médio quadrático do conjunto de teste: 0.10412817436752318
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8746346373718477
# Erro médio quadrático do conjunto de teste: 0.1108878468557841
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8837563173048412
# Erro médio quadrático do conjunto de teste: 0.10281956207382695
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8796407773469624
# Erro médio quadrático do conjunto de teste: 0.10645982885095694
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8680186029913222
# Erro médio quadrático do conjunto de teste: 0.11673984450330308
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8804281110385992
# Erro médio quadrático do conjunto de teste: 0.10576341848694303
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.881944562973872
# Erro médio quadrático do conjunto de teste: 0.10442209033666705
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.876504297372267
# Erro médio quadrático do conjunto de teste: 0.1092341000197157
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.7897042015773603
# Erro médio quadrático do conjunto de teste: 0.18601029663250773
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.790830326821387
# Erro médio quadrático do conjunto de teste: 0.18501421923934097
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.7935012252323301
# Erro médio quadrático do conjunto de teste: 0.1826517630732108
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.7762964955040786
# Erro médio quadrático do conjunto de teste: 0.19786964618946074
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.7802103427491861
# Erro médio quadrático do conjunto de teste: 0.19440778012985624
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.7863227659848158
# Erro médio quadrático do conjunto de teste: 0.1890012353118857
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.7858193681734188
# Erro médio quadrático do conjunto de teste: 0.18944649944423853
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.7869730390864854
# Erro médio quadrático do conjunto de teste: 0.188426057427016
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.7854256326256237
# Erro médio quadrático do conjunto de teste: 0.18979476539434048
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.7786609466803649
# Erro médio quadrático do conjunto de teste: 0.19577824794007587
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.7799109980622837
# Erro médio quadrático do conjunto de teste: 0.19467255571940073
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.7826934488571287
# Erro médio quadrático do conjunto de teste: 0.19221142952669235
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.7792244596737932
# Erro médio quadrático do conjunto de teste: 0.19527981088213148
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.7890074859203918
# Erro médio quadrático do conjunto de teste: 0.18662655376647466
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.7947517772522383
# Erro médio quadrático do conjunto de teste: 0.18154562802951382
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.7847173306561754
# Erro médio quadrático do conjunto de teste: 0.19042127082350593
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.7789674613392372
# Erro médio quadrático do conjunto de teste: 0.1955071303854376
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.7871510010633662
# Erro médio quadrático do conjunto de teste: 0.18826864695872705
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8637621333391483
# Erro médio quadrático do conjunto de teste: 0.12050476604974751
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8721383244927148
# Erro médio quadrático do conjunto de teste: 0.11309587907810104
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8649363573198252
# Erro médio quadrático do conjunto de teste: 0.11946614448623083
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8666385780777381
# Erro médio quadrático do conjunto de teste: 0.11796050057661234
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.87636105225954
# Erro médio quadrático do conjunto de teste: 0.10936080281696298
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8717484762915119
# Erro médio quadrático do conjunto de teste: 0.11344070660243258
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.872248756339829
# Erro médio quadrático do conjunto de teste: 0.11299820018582898
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8753929797865565
# Erro médio quadrático do conjunto de teste: 0.11021707978118231
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8689338548189827
# Erro médio quadrático do conjunto de teste: 0.1159302883199008
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8687128353588416
# Erro médio quadrático do conjunto de teste: 0.11612578388210779
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8747024435072106
# Erro médio quadrático do conjunto de teste: 0.11082787114800978
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8713757352215818
# Erro médio quadrático do conjunto de teste: 0.11377040257118158
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.867188764069283
# Erro médio quadrático do conjunto de teste: 0.11747385148396325
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.873389594387386
# Erro médio quadrático do conjunto de teste: 0.1119891090616724
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8684369884109129
# Erro médio quadrático do conjunto de teste: 0.11636977531224689
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8732225317272337
# Erro médio quadrático do conjunto de teste: 0.11213687889447077
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8758477480503841
# Erro médio quadrático do conjunto de teste: 0.10981482933068294
#
# 'n_estimators': 100, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.874788513080783
# Erro médio quadrático do conjunto de teste: 0.11075174111102704
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8748365808721439
# Erro médio quadrático do conjunto de teste: 0.11070922431232456
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8794752788289201
# Erro médio quadrático do conjunto de teste: 0.10660621517281503
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.871362900686883
# Erro médio quadrático do conjunto de teste: 0.11378175494067443
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.874189341810096
# Erro médio quadrático do conjunto de teste: 0.11128171853630195
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8796879420635144
# Erro médio quadrático do conjunto de teste: 0.10641811083765276
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8792019794687388
# Erro médio quadrático do conjunto de teste: 0.10684795321721771
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.884013910557701
# Erro médio quadrático do conjunto de teste: 0.10259171635491875
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8834662067850352
# Erro médio quadrático do conjunto de teste: 0.10307616988173417
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8759232831597851
# Erro médio quadrático do conjunto de teste: 0.10974801721074894
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8843183272936614
# Erro médio quadrático do conjunto de teste: 0.1023224544496376
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8856016569597799
# Erro médio quadrático do conjunto de teste: 0.10118732700694734
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8782425696170668
# Erro médio quadrático do conjunto de teste: 0.10769656794200172
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8854734394088531
# Erro médio quadrático do conjunto de teste: 0.10130073766403257
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8827232586081794
# Erro médio quadrático do conjunto de teste: 0.10373332048481845
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8785932586164897
# Erro médio quadrático do conjunto de teste: 0.10738637741371874
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8836987046826883
# Erro médio quadrático do conjunto de teste: 0.10287052144161657
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8859560966520679
# Erro médio quadrático do conjunto de teste: 0.10087381892549571
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8811754390567177
# Erro médio quadrático do conjunto de teste: 0.10510239383797385
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8085035738347941
# Erro médio quadrático do conjunto de teste: 0.16938192442374686
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8119585258661915
# Erro médio quadrático do conjunto de teste: 0.16632595917369586
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8063357398694637
# Erro médio quadrático do conjunto de teste: 0.1712994113253669
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8011354955070642
# Erro médio quadrático do conjunto de teste: 0.17589911804165345
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8041526776933876
# Erro médio quadrático do conjunto de teste: 0.1732303678446362
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8042462748650191
# Erro médio quadrático do conjunto de teste: 0.17314757951605456
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8090593513257892
# Erro médio quadrático do conjunto de teste: 0.16889032955244138
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8100702485412371
# Erro médio quadrático do conjunto de teste: 0.16799617335759184
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8146681976622517
# Erro médio quadrático do conjunto de teste: 0.1639292072730757
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.7989097708075236
# Erro médio quadrático do conjunto de teste: 0.17786781030602197
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8051643358513141
# Erro médio quadrático do conjunto de teste: 0.17233553858291012
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8033373237944865
# Erro médio quadrático do conjunto de teste: 0.17395156257003078
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.807513047230317
# Erro médio quadrático do conjunto de teste: 0.1702580624583779
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8116984530659753
# Erro médio quadrático do conjunto de teste: 0.16655599809542954
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8113463959608487
# Erro médio quadrático do conjunto de teste: 0.16686739873703718
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.7989521662516486
# Erro médio quadrático do conjunto de teste: 0.17783031079725048
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8035892382996697
# Erro médio quadrático do conjunto de teste: 0.1737287398023549
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8035240621623627
# Erro médio quadrático do conjunto de teste: 0.17378638923103945
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8703841196779493
# Erro médio quadrático do conjunto de teste: 0.11464750379146282
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8807466232425012
# Erro médio quadrático do conjunto de teste: 0.10548168889475294
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8748593493095307
# Erro médio quadrático do conjunto de teste: 0.11068908523287585
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8706183299932188
# Erro médio quadrático do conjunto de teste: 0.1144403406881367
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8778277155467881
# Erro médio quadrático do conjunto de teste: 0.10806351359308253
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8772958552419868
# Erro médio quadrático do conjunto de teste: 0.10853395329661059
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.875618217034745
# Erro médio quadrático do conjunto de teste: 0.11001785351198207
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8805577755055355
# Erro médio quadrático do conjunto de teste: 0.10564872800744493
#
# 'n_estimators': 100, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': True
# ...
# R² do conjunto de teste: 0.8734135096968281
# Erro médio quadrático do conjunto de teste: 0.11196795555391444
#
# 'n_estimators': 300, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8709026967641396
# Erro médio quadrático do conjunto de teste: 0.11418881332616294
#
# 'n_estimators': 300, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.872723492346525
# Erro médio quadrático do conjunto de teste: 0.11257828791896479
#
# 'n_estimators': 300, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8763249892255761
# Erro médio quadrático do conjunto de teste: 0.10939270119864916
#
# 'n_estimators': 300, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8707009629423694
# Erro médio quadrático do conjunto de teste: 0.11436725040531405
#
# 'n_estimators': 300, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8687378562340803
# Erro médio quadrático do conjunto de teste: 0.11610365248214607
#
# 'n_estimators': 300, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8770294443980665
# Erro médio quadrático do conjunto de teste: 0.10876959832839636
#
# 'n_estimators': 300, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8739053355894262
# Erro médio quadrático do conjunto de teste: 0.11153292698529864
#
# 'n_estimators': 300, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8725048696392947
# Erro médio quadrático do conjunto de teste: 0.11277166351147558
#
# 'n_estimators': 300, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8758703266789046
# Erro médio quadrático do conjunto de teste: 0.10979485814048254
#
# 'n_estimators': 300, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8701870984622517
# Erro médio quadrático do conjunto de teste: 0.11482177248845854
#
# 'n_estimators': 300, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8692983071700675
# Erro médio quadrático do conjunto de teste: 0.11560792386734313
#
# 'n_estimators': 300, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8767433562234093
# Erro médio quadrático do conjunto de teste: 0.10902264830195844
#
# 'n_estimators': 300, 'max_features': sqrt, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8756182040230521
# Erro médio quadrático do conjunto de teste: 0.11001786502105106
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8762961113138475
# Erro médio quadrático do conjunto de teste: 0.10941824421456792
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8814188733787609
# Erro médio quadrático do conjunto de teste: 0.10488707193999283
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8742715887924969
# Erro médio quadrático do conjunto de teste: 0.11120896964779226
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8784401200649314
# Erro médio quadrático do conjunto de teste: 0.10752183112993607
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8811065688659738
# Erro médio quadrático do conjunto de teste: 0.10516331072126635
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8772419329868874
# Erro médio quadrático do conjunto de teste: 0.10858164847046274
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.887241222475061
# Erro médio quadrático do conjunto de teste: 0.09973710275076443
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8825764828954981
# Erro médio quadrático do conjunto de teste: 0.10386314615922124
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8769299068416763
# Erro médio quadrático do conjunto de teste: 0.10885764103076655
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8831153164322948
# Erro médio quadrático do conjunto de teste: 0.1033865385105336
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.885256582805096
# Erro médio quadrático do conjunto de teste: 0.10149255110725938
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.880825067089546
# Erro médio quadrático do conjunto de teste: 0.10541230394570855
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8855488136338603
# Erro médio quadrático do conjunto de teste: 0.10123406784914715
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8849133023736381
# Erro médio quadrático do conjunto de teste: 0.10179618862813514
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8757672092036805
# Erro médio quadrático do conjunto de teste: 0.10988606734341624
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8861237383160271
# Erro médio quadrático do conjunto de teste: 0.1007255369537449
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8848187317863129
# Erro médio quadrático do conjunto de teste: 0.10187983795985274
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8798861453160839
# Erro médio quadrático do conjunto de teste: 0.106242796608455
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.80754661375231
# Erro médio quadrático do conjunto de teste: 0.1702283722850142
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8099331190327697
# Erro médio quadrático do conjunto de teste: 0.16811746679635006
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8158896975163222
# Erro médio quadrático do conjunto de teste: 0.1628487693760922
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.800047229216846
# Erro médio quadrático do conjunto de teste: 0.17686170853075026
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8018322681161979
# Erro médio quadrático do conjunto de teste: 0.1752828105325044
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8045057901868486
# Erro médio quadrático do conjunto de teste: 0.17291803369366404
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8071020520568039
# Erro médio quadrático do conjunto de teste: 0.17062159484805536
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8143777295049217
# Erro médio quadrático do conjunto de teste: 0.16418613141760224
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8125880385504738
# Erro médio quadrático do conjunto de teste: 0.1657691442396098
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8009792793099878
# Erro médio quadrático do conjunto de teste: 0.17603729398893786
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8040305036787135
# Erro médio quadrático do conjunto de teste: 0.17333843288863973
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8040330015747366
# Erro médio quadrático do conjunto de teste: 0.17333622345609903
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8072767284268137
# Erro médio quadrático do conjunto de teste: 0.1704670905562724
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8128241536849969
# Erro médio quadrático do conjunto de teste: 0.1655602962904758
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.811836341685545
# Erro médio quadrático do conjunto de teste: 0.16643403320967923
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8016500347326793
# Erro médio quadrático do conjunto de teste: 0.17544399913436381
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8048686300419963
# Erro médio quadrático do conjunto de teste: 0.1725970955218492
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8060355411533557
# Erro médio quadrático do conjunto de teste: 0.17156494231861913
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8742213903112801
# Erro médio quadrático do conjunto de teste: 0.11125337107878458
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8785497141895433
# Erro médio quadrático do conjunto de teste: 0.10742489321780868
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': True
# R² do conjunto de teste: 0.8760742857198908
# Erro médio quadrático do conjunto de teste: 0.10961445281617611
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8705503213019036
# Erro médio quadrático do conjunto de teste: 0.11450049556017894
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.879504430936491
# Erro médio quadrático do conjunto de teste: 0.10658042962589775
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 10, 'bootstrap': False
# R² do conjunto de teste: 0.8769108404929282
# Erro médio quadrático do conjunto de teste: 0.10887450554833152
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8759345614501584
# Erro médio quadrático do conjunto de teste: 0.10973804136646878
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8814760265060763
# Erro médio quadrático do conjunto de teste: 0.10483651900339049
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': True
# R² do conjunto de teste: 0.8774693755264388
# Erro médio quadrático do conjunto de teste: 0.10838047158264026
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8731105507339341
# Erro médio quadrático do conjunto de teste: 0.11223592803352689
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8776742032784894
# Erro médio quadrático do conjunto de teste: 0.10819929786826606
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 50, 'bootstrap': False
# R² do conjunto de teste: 0.8781363859651802
# Erro médio quadrático do conjunto de teste: 0.10779048923160003
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8753838362955666
# Erro médio quadrático do conjunto de teste: 0.11022516735822399
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8833212589280537
# Erro médio quadrático do conjunto de teste: 0.10320437878593289
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': True
# R² do conjunto de teste: 0.8755699296888122
# Erro médio quadrático do conjunto de teste: 0.11006056451052756
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 1, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8701327853426848
# Erro médio quadrático do conjunto de teste: 0.1148698133887403
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 5, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8790288233975279
# Erro médio quadrático do conjunto de teste: 0.10700111277823257
#
# 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': 100, 'min_samples_leaf': 10, 'max_depth': 80, 'bootstrap': False
# R² do conjunto de teste: 0.8780327810526598
# Erro médio quadrático do conjunto de teste: 0.10788212958131244
#
# Parâmetros do melhor modelo: 'n_estimators': 300, 'max_features': log2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'max_depth': 50, 'bootstrap': True
# R² do melhor modelo: 0.887241222475061 MSE: 0.09973710275076443
